# %% [markdown]
# - p(x) is Gaussian
# - x -> x_gamma --> r
# - r generated by nnetwork
#
#
#
# Matrix p(r=0....R, x_gamma_ix=0....N)
#
# where x_gamma_ix is the index of the (PC1,PC2) pairs from the 2D PC meshgrid used to calculate the 2D tuning curve.
#
# note: 2D PCs important to visualize SSI and Ilocal in 2D

# %% [markdown]
# ## Setup
#
# setup fisher_info_limits2

# %%
import os
import numpy as np
from numpy import sqrt, cumprod, hstack, random
from matplotlib import pyplot as plt;

# setup project path
main_dir = '/home/steeve/steeve/idv/code/fisher-info-limits'
os.chdir(main_dir)

# %% [markdown]
# ## Functions

# %%
# Out:
# array([-0.00639022])
